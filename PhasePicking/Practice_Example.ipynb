# %%
from EQLocateDL import *
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 2025-09-24 09:29:28.757284: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-24 09:29:29.433906: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = read_data()
# Out:
# 지진 자료를 불러옵니다...
# ...
# Station: PUAA  | 기간(UTC): 2024-06-11 23:26:48 ~ 2024-06-11 23:28:48
# Station: MSMB  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: SENA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: GIJA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: TAIA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: SMWA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: MND   | 기간(UTC): 2024-06-11 23:26:48 ~ 2024-06-11 23:28:48
# Station: JEU2  | 기간(UTC): 2024-06-11 23:26:48 ~ 2024-06-11 23:28:48
# Station: NACA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: IKSB  | 기간(UTC): 2024-06-11 23:26:48 ~ 2024-06-11 23:28:48
# Station: CHOA  | 기간(UTC): 2024-06-11 23:26:48 ~ 2024-06-11 23:28:48
# Station: GOCB  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# Station: JAGA  | 기간(UTC): 2024-06-11 23:26:49 ~ 2024-06-11 23:28:49
# ...
# 총 13건의 자료를 불러왔습니다.

# %%
plot_data(data, station="PUAA")

# %%
picked = picking(data)
# Out:
# 인공지능 모델을 이용하여 지진파의 도달시각을 결정합니다...
# ...
# Station: CHOA  | P파 도달시각: 2024-06-11 23:26:56.678 (확률 98.38%) | S파 도달시각: 2024-06-11 23:27:01.398 (확률 84.29%)
# Station: GIJA  | P파 도달시각: 2024-06-11 23:26:53.600 (확률 97.93%) | S파 도달시각: 2024-06-11 23:26:56.210 (확률 96.06%)
# Station: GOCB  | P파 도달시각: 2024-06-11 23:26:56.930 (확률 97.89%) | S파 도달시각: 2024-06-11 23:27:01.890 (확률 94.66%)
# Station: IKSB  | P파 도달시각: 2024-06-11 23:26:56.028 (확률 95.08%) | S파 도달시각: 2024-06-11 23:27:00.248 (확률 81.27%)
# Station: JAGA  | P파 도달시각: 2024-06-11 23:26:57.323 (확률 98.55%) | S파 도달시각: 2024-06-11 23:27:02.633 (확률 93.33%)
# Station: JEU2  | P파 도달시각: 2024-06-11 23:26:55.238 (확률 98.37%) | S파 도달시각: 2024-06-11 23:26:58.838 (확률 95.84%)
# Station: MND   | P파 도달시각: 2024-06-11 23:26:55.228 (확률 97.37%) | S파 도달시각: 2024-06-11 23:26:59.018 (확률 95.76%)
# Station: MSMB  | P파 도달시각: 2024-06-11 23:26:52.960 (확률 98.22%) | S파 도달시각: 2024-06-11 23:26:54.990 (확률 87.96%)
# ...

# %%
 result = calc_hypocenter(picked)
# Out:
# 선형화 역산을 수행합니다...
# ...
# Iteration 1  | 위도: 35.69883° | 경도: 126.72295° | 깊이:  10.40 km | 시각(UTC): 2024-06-11 23:26:49.919    | RMS:   0.509
# Iteration 2  | 위도: 35.69925° | 경도: 126.72289° | 깊이:   9.79 km | 시각(UTC): 2024-06-11 23:26:49.938    | RMS:   0.085
# Iteration 3  | 위도: 35.69924° | 경도: 126.72289° | 깊이:   9.77 km | 시각(UTC): 2024-06-11 23:26:49.938    | RMS:   0.069
# Iteration 4  | 위도: 35.69924° | 경도: 126.72289° | 깊이:   9.77 km | 시각(UTC): 2024-06-11 23:26:49.938    | RMS:   0.069
# Iteration 5  | 위도: 35.69924° | 경도: 126.72289° | 깊이:   9.77 km | 시각(UTC): 2024-06-11 23:26:49.938    | RMS:   0.069
# ...
#
#
# ...
# 결정된 지진의 진원 요소
# ...
#           위도 |           경도 |           깊이 |                   진원시(UTC) |          RMS
#      35.69924°|     126.72289°|        9.77 km |       2024-06-11 23:26:49.938 |        0.069
# ...

# %%
plot_hypocenter(picked, result, html_out="hypocenter.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
